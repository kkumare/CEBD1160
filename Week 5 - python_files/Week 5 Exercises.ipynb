# %%
print('Basic Q1')

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os

os.chdir('/Users/Kate/Desktop/python_files/week5')
print('\n')
f1 = pd.read_csv('train_titanic.csv')
f1.head()
# Out:
# Basic Q1
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# ...

# %%
print('Basic q2')
print('\n')
f1.info()
# Out:
# Basic q2
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
f1.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
print('Output text:')
print('From this file, we can learn more about the passengers on this trip. From the above, we can see that there were a lot of young adults on-board, with the mean age being 29. ')
# Out:
# Output text:
# From this file, we can learn more about the passengers on this trip. From the above, we can see that there were a lot of young adults on-board, with the mean age being 29.

# %%
print('Basic q3')
f1.drop (index=1)
# Out:
# Basic q3
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# 25            26         1       3
# ...

# %%
print('Basic q4')
print('\n')

del f1['Embarked']

f1.info()
# Out:
# Basic q4
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 76.6+ KB

# %%
print('Basic q5')
f1.dropna(0)
# Out:
# Basic q5
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# 21            22         1       2
# 23            24         1       1
# 27            28         0       1
# 52            53         1       1
# 54            55         0       1
# 61            62         1       1
# 62            63         0       1
# 66            67         1       2
# 75            76         0       3
# 88            89         1       1
# 92            93         0       1
# 96            97         0       1
# 97            98         1       1
# 102          103         0       1
# 110          111         0       1
# 118          119         0       1
# 123          124         1       2
# 124          125         0       1
# 136          137         1       1
# 137          138         0       1
# ...

# %%
print('Basic q6')

f1['Fare'].hist(figsize=(10, 5), bins=50, color='g', xlabelsize=8)
# Out:
# Basic q6

# %%
print('Basic q7')
f1['Survived'].hist(figsize=(10,5), bins=50, xlabelsize=8)
# Out:
# Basic q7

# %%
print('Basic q8')
print('\n')
f1_corr = f1.corr()['Fare']
corr_list = f1_corr[abs(f1_corr) < 0.5].sort_values(ascending=False)
print("There is {} strongly correlated values with Fare:\n{}".format(len(corr_list), corr_list))
# Out:
# Basic q8
#
#
# There is 5 strongly correlated values with Fare:
# Survived       0.257307
# Parch          0.216225
# SibSp          0.159651
# Age            0.096067
# PassengerId    0.012658
# Name: Fare, dtype: float64

# %%
f1_corr2 = f1.corr()['Fare']
corr_list = f1_corr2[abs(f1_corr2) > 0.5].sort_values(ascending=False)
print("There is {} strongly correlated values with Fare:\n{}".format(len(corr_list), corr_list))
# Out:
# There is 2 strongly correlated values with Fare:
# Fare      1.0000
# Pclass   -0.5495
# Name: Fare, dtype: float64

# %%
print('Advanced q1')
print('\n')

f1['doubledFare']=f1['Fare']*2
f1.info()
# Out:
# Advanced q1
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# doubledFare    891 non-null float64
# dtypes: float64(3), int64(5), object(4)
# memory usage: 83.6+ KB

# %%
f1.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin  doubledFare
# 0      0         A/5 21171   7.2500   NaN      14.5000
# 1      0          PC 17599  71.2833   C85     142.5666
# 2      0  STON/O2. 3101282   7.9250   NaN      15.8500
# 3      0            113803  53.1000  C123     106.2000
# ...

# %%
print('Advanced q3')

plt.scatter(f1['Age'], f1['Fare'], color='b', alpha=0.5)
# Out:
# Advanced q3
